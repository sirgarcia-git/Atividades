# %%
from osgeo import gdal
import json

gdal.UseExceptions()

ds = gdal.Open('/home/jovyan/Downloads/T18LXR_20260705T151931_B05.jp2')
print(f"Width: {ds.RasterXSize}")
print(f"Height: {ds.RasterYSize}")
print(f"Number of band(s): {ds.RasterCount}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 6
#       2 import json
#       3
#       4 gdal.UseExceptions()
#       5
# ----> 6 ds = gdal.Open('/home/jovyan/Downloads/T18LXR_20260705T151931_B05.jp2')
#       7 print(f"Width: {ds.RasterXSize}")
#       8 print(f"Height: {ds.RasterYSize}")
#       9 print(f"Number of band(s): {ds.RasterCount}")
#
# File /opt/conda/envs/geospatial/lib/python3.11/site-packages/osgeo/gdal.py:9192, in Open(*args)
#    9188 _WarnIfUserHasNotSpecifiedIfUsingExceptions()
#    9189 from . import gdal
# -> 9192 return _gdal.Open(*args)
#
# ...
