# %% [markdown]
# # Notebook de Atividades
#
# Este é um notebook Jupyter para organizar e documentar atividades.

# %%
# Exemplo básico
print('Olá! Este é um notebook de exemplo.')

# %% [markdown]
# ## Como usar
#
# Você pode adicionar mais células de código e documentação conforme necessário.
